# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathambiradr12345/Data-Analyst/blob/main/Column_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv('covid.csv')

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=['has_covid']),df['has_covid'],test_size=0.2)

# %%
x_train
# Out:
#     age  gender  fever   cough       city
# 96   51  Female  101.0  Strong    Kolkata
# 70   68  Female  101.0  Strong      Delhi
# 22   71  Female   98.0  Strong    Kolkata
# 74   34  Female  104.0  Strong      Delhi
# 15   70    Male  103.0  Strong    Kolkata
# ..  ...     ...    ...     ...        ...
# 68   54  Female  104.0  Strong    Kolkata
# 94   79    Male    NaN  Strong    Kolkata
# 5    84  Female    NaN    Mild  Bangalore
# 53   83    Male   98.0    Mild      Delhi
# 20   12    Male   98.0  Strong  Bangalore
#
# [80 rows x 5 columns]

# %%
#column transformer
from sklearn.compose import ColumnTransformer
tr=ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(sparse_output=False,drop='first'),['gender','city']) # Changed 'sparse' to 'sparse_output'

],remainder='passthrough')

# %%
tr.fit_transform(x_train).shape
# Out:
# (80, 7)

# %%
tr.fit_transform(x_test).shape
# Out:
# (20, 7)
